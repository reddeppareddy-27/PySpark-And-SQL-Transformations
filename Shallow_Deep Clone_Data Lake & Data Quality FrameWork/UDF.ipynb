# %%
from pyspark.sql import Row

data =[Row(id=1,name='Alice' ,age=30),Row(id=2,name='Bob',age=20),Row(id=3,name='Charlie',age=40)]
df=spark.createDataFrame(data)
df.write.format('delta').mode('overwrite').saveAsTable('my_files.my_schema.people_delta_demo')
delta_df=spark.read.table('my_files.my_schema.people_delta_demo')
display(delta_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>30</td></tr><tr><td>2</td><td>Bob</td><td>20</td></tr><tr><td>3</td><td>Charlie</td><td>40</td></tr></tbody></table></div>

# %%
df.write.format('delta').mode('overwrite').save("/Volumes/my_files/my_schema/csv_files/my_files/mytable")

# %%
df2=spark.read.load("/Volumes/my_files/my_schema/csv_files/my_files/mytable")
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>30</td></tr><tr><td>2</td><td>Bob</td><td>20</td></tr><tr><td>3</td><td>Charlie</td><td>40</td></tr></tbody></table></div>

# %%
# %sql
describe history my_files.my_schema.people_delta_demo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import lit

data=[Row(id=7,name='Reddy',country='USA'),
      Row(id=8,name='Janu',country='India'),
      Row(id=9,name='Mouni',country='Iran')]
df=spark.createDataFrame(data)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>country</th></tr></thead><tbody><tr><td>7</td><td>Reddy</td><td>USA</td></tr><tr><td>8</td><td>Janu</td><td>India</td></tr><tr><td>9</td><td>Mouni</td><td>Iran</td></tr></tbody></table></div>

# %%
df.write.format('delta').mode('append').\
    option('mergeSchema','true')\
    .saveAsTable('my_files.my_schema.people_delta_demo')
result_df=spark.read.table('my_files.my_schema.people_delta_demo')
display(result_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th><th>country</th></tr></thead><tbody><tr><td>7</td><td>Reddy</td><td>null</td><td>USA</td></tr><tr><td>8</td><td>Janu</td><td>null</td><td>India</td></tr><tr><td>9</td><td>Mouni</td><td>null</td><td>Iran</td></tr><tr><td>1</td><td>Alice</td><td>30</td><td>null</td></tr><tr><td>2</td><td>Bob</td><td>20</td><td>null</td></tr><tr><td>3</td><td>Charlie</td><td>40</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
describe history my_files.my_schema.people_delta_demo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from my_files.my_schema.people_delta_demo version as of 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>30</td></tr><tr><td>2</td><td>Bob</td><td>20</td></tr><tr><td>3</td><td>Charlie</td><td>40</td></tr></tbody></table></div>

# %%
# %sql
restore my_files.my_schema.people_delta_demo version as of 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_size_after_restore</th><th>num_of_files_after_restore</th><th>num_removed_files</th><th>num_restored_files</th><th>removed_files_size</th><th>restored_files_size</th></tr></thead><tbody><tr><td>1088</td><td>1</td><td>2</td><td>1</td><td>2322</td><td>1088</td></tr></tbody></table></div>

# %%
# %sql
describe history my_files.my_schema.people_delta_demo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import lit

data=[Row(id=1,name='Reddy',age=21),
      Row(id=8,name='Janu',age=20),
      Row(id=9,name='Mouni',age=18)]
df=spark.createDataFrame(data)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>Reddy</td><td>21</td></tr><tr><td>8</td><td>Janu</td><td>20</td></tr><tr><td>9</td><td>Mouni</td><td>18</td></tr></tbody></table></div>

# %%
df.createOrReplaceTempView('update')

merge_sql="""
MERGE INTO my_files.my_schema.people_delta_demo AS target USING update as source
 ON target.id=source.id
WHEN MATCHED THEN UPDATE SET target.name=source.name,target.age=source.age
WHEN NOT MATCHED THEN INSERT (id,name,age) values(source.id,source.name,source.age)
"""
spark.sql(merge_sql)
result=spark.read.table('my_files.my_schema.people_delta_demo').select("id","name","age")
display(result)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>2</td><td>Bob</td><td>20</td></tr><tr><td>3</td><td>Charlie</td><td>40</td></tr><tr><td>1</td><td>Reddy</td><td>21</td></tr><tr><td>9</td><td>Mouni</td><td>18</td></tr><tr><td>8</td><td>Janu</td><td>20</td></tr></tbody></table></div>

# %%
# %sql
describe history my_files.my_schema.people_delta_demo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
optimize "/Volumes/my_files/my_schema/csv_files/my_files/mytable"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/Volumes/my_files/my_schema/csv_files/my_files/mytable</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, null, null, 0, 0, 1, 1, true, 0, 0, 1773109138511, 1773109139136, 8, 0, null, List(0, 0), null, 3, 3, 0, 0, null, null)</td></tr></tbody></table></div>

# %%
# %sql
optimize my_files.my_schema.people_delta_demo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, null, null, 0, 0, 1, 1, true, 0, 0, 1773109158992, 1773109159545, 8, 0, null, List(0, 0), null, 3, 3, 0, 0, null, null)</td></tr></tbody></table></div>

# %%
# %sql
optimize "/Volumes/my_files/my_schema/csv_files/my_files/mytable" zorder by id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/Volumes/my_files/my_schema/csv_files/my_files/mytable</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, List(minCubeSize(107374182400), List(0, 0), List(1, 1067), 0, List(0, 0), 0, null), null, 0, 0, 1, 1, false, 0, 0, 1773109260920, 1773109261653, 8, 0, null, List(0, 0), null, 3, 3, 0, 0, null, null)</td></tr></tbody></table></div>

# %%
# %sql
optimize my_files.my_schema.people_delta_demo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, null, null, 0, 0, 1, 1, true, 0, 0, 1773109529297, 1773109529789, 8, 0, null, List(0, 0), null, 3, 3, 0, 0, null, null)</td></tr></tbody></table></div>

# %%
# %sql
vacuum my_files.my_schema.people_delta_demo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td></td></tr></tbody></table></div>

# %%
# %sql
vacuum my_files.my_schema.people_delta_demo dry run retain 0 hours
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# File <command-6717547627757461>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'vacuum my_files.my_schema.people_delta_demo dry run retain 0 hours\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:192, in SqlMagic.sql(self, line, cell)
# ...

# %%
# %sql
SET spark.databricks.delta.retentionDurationCheck.enabled=false;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-6717547627757462>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SET spark.databricks.delta.retentionDurationCheck.enabled=false;\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:192, in SqlMagic.sql(self, line, cell)
# ...

# %%
# %sql
SET 'delta.logRetentionDuration'='interval 30 days',
SET 'delta.deletedFileRetentionDuration'='interval 7 days'
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# File <command-6717547627757463>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', "SET 'delta.logRetentionDuration'='interval 30 days',\nSET 'delta.deletedFileRetentionDuration'='interval 7 days'\n")
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...
