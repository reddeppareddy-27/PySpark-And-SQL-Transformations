# %%
data=[("OrderID :564974",),
      ("Invoice # 9821 Processed",),
      ("No numbers here",),
      ("ref-44965,")]
df=spark.createDataFrame(data,["text_col"])
df.createOrReplaceTempView("orders")
display(df)
