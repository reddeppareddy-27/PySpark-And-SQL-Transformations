# %%
df=spark.read.table('samples.bakehouse.media_customer_reviews')

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>review</th><th>franchiseID</th><th>review_date</th><th>new_id</th></tr></thead><tbody><tr><td>Title: A Delightful Cookie Experience at Bakehouse in Tenmonkan, Kagoshima
#
# ...

# %%
df.show()
# Out:
# +--------------------+-----------+--------------------+------+
# |              review|franchiseID|         review_date|new_id|
# +--------------------+-----------+--------------------+------+
# |Title: A Delightf...|    3000037|2024-05-20 17:24:...|     1|
# |"Sweet tooth heav...|    3000017|2024-05-20 17:17:...|     2|
# |**4.5/5 stars**\n...|    3000007|2024-05-20 17:17:...|     3|
# |Bakehouse in Fitz...|    3000003|2024-05-31 15:13:...|     4|
# |Title: A Sweet Es...|    3000034|2024-05-20 17:24:...|     5|
# |I recently visite...|    3000022|2024-05-31 15:13:...|     6|
# |**4.5/5 stars**\n...|    3000040|2024-05-20 17:17:...|     7|
# |"I stopped by Bak...|    3000004|2024-05-31 15:23:...|     8|
# |**5/5 stars**\n\n...|    3000026|2024-05-20 17:17:...|     9|
# |"I stopped by Bak...|    3000007|2024-05-31 15:23:...|    10|
# |I recently visite...|    3000026|2024-05-31 15:13:...|    11|
# |**4.5/5 stars**\n...|    3000001|2024-05-20 17:17:...|    12|
# ...

# %%
df.write.saveAsTable("practice_tables.test_schema.test_table1")

# %%
df2=df.limit(10)

# %%
df2.count()
# Out:
# 10

# %%
df2.printSchema()
# Out:
# root
#  |-- review: string (nullable = true)
#  |-- franchiseID: long (nullable = true)
#  |-- review_date: timestamp (nullable = true)
#  |-- new_id: integer (nullable = true)

# %%
df3=spark.read.csv("/Volumes/my_files/my_schema/csv_files/my_files/emp.csv")
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df3=spark.read.\
    option("header","true").\
    csv("/Volumes/my_files/my_schema/csv_files/my_files/emp.csv")
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df3=spark.read.\
    option("header","true").\
    option("inferSchema","true").\
    csv("/Volumes/my_files/my_schema/csv_files/my_files/emp.csv")
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
schema_str="id INT,customer_name STRING,product STRING,quantity INT,price DOUBLE,remarks STRING"

df3=spark.read.\
schema(schema_str).\
csv("/Volumes/my_files/my_schema/csv_files/my_files/sales_no_header.csv")    
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.types import StructType,StructField,StringType,IntegerType,DoubleType

schema=StructType([
    StructField("id",IntegerType(),True),
    StructField("customer_name",StringType(),True),
    StructField("product",StringType(),True),
    StructField("quantity",IntegerType(),True),
    StructField("price",DoubleType(),True),
    StructField("remarks",StringType(),True)
])
df3=spark.read.\
schema(schema).\
csv("/Volumes/my_files/my_schema/csv_files/my_files/sales_no_header.csv")
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df3=spark.read.\
    option("header","true").\
    option("inferSchema","true").\
    option("delimiter","|").\
    csv("/Volumes/my_files/my_schema/csv_files/my_files/sales_pipes.csv")
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df3=spark.read.\
    option("header","true").\
    option("inferSchema","true").\
    option("delimiter","|").\
    option("quote","'").\
    csv("/Volumes/my_files/my_schema/csv_files/my_files/sales_pipe_single_qoute.csv")
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df3=spark.read.\
    option("header","true").\
    option("inferSchema","true").\
    option("delimiter","|").\
    option("quote","'").\
    option("escape","#").\
    option("multiLine","true").\
    csv("/Volumes/my_files/my_schema/csv_files/my_files/sales_pipe_single_qoute_escape_multiline.csv")
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>customer_name</th><th>product</th><th>quantity</th><th>price</th><th>remarks</th></tr></thead><tbody><tr><td>1</td><td>John Doe</td><td>Laptop, 16GB RAM</td><td>2</td><td>85000</td><td>Delivered on time</td></tr><tr><td>2</td><td>Jane Smith</td><td>Smartphone, 128GB</td><td>1</td><td>55000</td><td>Customer said 'excellent' work
# ...

# %%
df4=spark.read.json("/Volumes/my_files/my_schema/csv_files/my_files/sales.json")
display(df4)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df=spark.read.option("multiline","true").json("/Volumes/my_files/my_schema/csv_files/my_files/sales_ml.json")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.write.format("json").save("/Volumes/my_files/my_schema/csv_files/my_files/sales_ml_Written")

# %%
df.write.format("csv").save("/Volumes/my_files/my_schema/csv_files/my_files/sales_ml_csv_written")

# %%
df=spark.read.format("json").\
    load("/Volumes/my_files/my_schema/csv_files/my_files/missing_json.json")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df=spark.read.format("json").\
    option("mode","DROPMALFORMED").\
    load("/Volumes/my_files/my_schema/csv_files/my_files/missing_json.json")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>id</th><th>price</th><th>product</th><th>quantity</th><th>remarks</th></tr></thead><tbody><tr><td>John Doe</td><td>1</td><td>85000</td><td>Laptop, 16GB RAM</td><td>2</td><td>Delivered on time</td></tr><tr><td>Alice Wong</td><td>4</td><td>2500</td><td>Keyboard</td><td>null</td><td>Missing quantity</td></tr><tr><td>null</td><td>5</td><td>null</td><td>Monitor, 27-inch</td><td>2</td><td>No price info</td></tr><tr><td>Mark Davis</td><td>7</td><td>150</td><td>USB Cable</td><td>2</td><td></td></tr></tbody></table></div>

# %%
df=spark.read.format("json").\
    option("mode","FAILFAST").\
    load("/Volumes/my_files/my_schema/csv_files/my_files/missing_json.json")
display(df)
# Out:
# ---------------------------------------------------------------------------
# SparkException                            Traceback (most recent call last)
# File <command-5001301951295632>, line 4
#       1 df=spark.read.format("json").\
#       2     option("mode","FAILFAST").\
#       3     load("/Volumes/my_files/my_schema/csv_files/my_files/missing_json.json")
# ----> 4 display(df)
#
# File /databricks/python_shell/lib/dbruntime/display.py:133, in Display.display(self, input, *args, **kwargs)
#     131     pass
#     132 elif self._cf_helper is not None and isinstance(input, ConnectDataFrame):
# --> 133     self.display_connect_table(input, **kwargs)
#     134 elif isinstance(input, ConnectDataFrame):
#     135     if input.isStreaming:
#
# File /databricks/python_shell/lib/dbruntime/display.py:93, in Display.display_connect_table(self, df, **kwargs)
#      88 except Exception as e:
#      89     raise type(
#      90         e
# ...

# %%
df=spark.read.format("csv").\
    load("/Volumes/my_files/my_schema/csv_files/my_files/missing_csv.csv")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
schema_str="id INT, customer_name STRING, product STRING, quantity INT, price DOUBLE, remarks STRING,_corrupt_record STRING"

df=spark.read.\
    schema(schema_str).\
    format("csv").\
    option("mode","PERMISSIVE").\
    load("/Volumes/my_files/my_schema/csv_files/my_files/missing_csv.csv")

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
schema_str="id INT, customer_name STRING, product STRING, quantity INT, price DOUBLE, remarks STRING,_corrupt_record STRING"

df=spark.read.\
    schema(schema_str).\
    format("csv").\
    option("mode","DROPMALFORMED").\
    load("/Volumes/my_files/my_schema/csv_files/my_files/missing_csv.csv")

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
schema_str="id INT, customer_name STRING, product STRING, quantity INT, price DOUBLE, remarks STRING,_corrupt_record STRING"

df=spark.read.\
    schema(schema_str).\
    format("csv").\
    option("badRecordsPath","/Volumes/my_files/my_schema/csv_files/my_files/bad_records").\
    load("/Volumes/my_files/my_schema/csv_files/my_files/missing_csv.csv")

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df2=spark.read.format("json").option("recursiveFileLookup","true").load("/Volumes/my_files/my_schema/csv_files/my_files/bad_records")
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>reason</th><th>record</th></tr></thead><tbody><tr><td>dbfs:/Volumes/my_files/my_schema/csv_files/my_files/missing_csv.csv</td><td>java.lang.NumberFormatException: For input string: "xx"</td><td>6,Tom Brown,"Mouse",xx,700,"Delivered, no issues"</td></tr></tbody></table></div>

# %%
df=spark.read.text("/Volumes/my_files/my_schema/csv_files/log_files/")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df=spark.read.text("/Volumes/my_files/my_schema/csv_files/log_files/",wholetext=True)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>INFO 2025-10-10 09:10:12 Spark context initialized
# INFO 2025-10-10 09:10:15 Loading configuration settings
# INFO 2025-10-10 09:10:40 Starting streaming job
# WARN 2025-10-10 09:11:05 Stream batch delayed by 15 seconds
# ERROR 2025-10-10 09:11:30 Failed to connect to Kafka topic
# INFO 2025-10-10 09:12:00 Attempting reconnection
# INFO 2025-10-10 09:12:20 Stream batch processed
# WARN 2025-10-10 09:12:45 High CPU usage detected
# INFO 2025-10-10 09:13:10 Streaming job finished</td></tr><tr><td>INFO 2025-10-10 08:01:23 Starting Spark application
# ...

# %%
df=spark.read.format("binaryFile").load("/Volumes/my_files/my_schema/csv_files/log_files/")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>modificationTime</th><th>length</th><th>content</th></tr></thead><tbody><tr><td>dbfs:/Volumes/my_files/my_schema/csv_files/log_files/log2.txt</td><td>2026-03-05T06:57:59.000Z</td><td>475</td><td>...</td></tr><tr><td>dbfs:/Volumes/my_files/my_schema/csv_files/log_files/log1.txt</td><td>2026-03-05T06:57:59.000Z</td><td>471</td><td>...</td></tr></tbody></table></div>

# %%
df=spark.read.text("/Volumes/my_files/my_schema/csv_files/log_files/",wholetext=True)
df2=df.selectExpr("value","_metadata.file_path","_metadata.file_name","_metadata.file_size","_metadata.file_modification_time")
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th><th>file_path</th><th>file_name</th><th>file_size</th><th>file_modification_time</th></tr></thead><tbody><tr><td>INFO 2025-10-10 09:10:12 Spark context initialized
# INFO 2025-10-10 09:10:15 Loading configuration settings
# INFO 2025-10-10 09:10:40 Starting streaming job
# WARN 2025-10-10 09:11:05 Stream batch delayed by 15 seconds
# ERROR 2025-10-10 09:11:30 Failed to connect to Kafka topic
# INFO 2025-10-10 09:12:00 Attempting reconnection
# INFO 2025-10-10 09:12:20 Stream batch processed
# WARN 2025-10-10 09:12:45 High CPU usage detected
# ...
