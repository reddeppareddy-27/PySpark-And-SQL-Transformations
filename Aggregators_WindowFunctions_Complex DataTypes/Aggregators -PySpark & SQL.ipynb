# %%
df=spark.read.table("samples.bakehouse.sales_transactions")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.count()
# Out:
# 3333

# %%
df.first()
# df.last()
# Out:
# Row(transactionID=1002961, customerID=2000253, franchiseID=3000047, dateTime=datetime.datetime(2024, 5, 14, 12, 17, 1, 495952), product='Golden Gate Ginger', quantity=8, unitPrice=3, totalPrice=24, paymentMethod='amex', cardNumber=378154478982993)

# %%
from pyspark.sql.functions import min,max,sum,avg,count
df2=df.select(min("quantity"),
              max("quantity"),
              sum("totalPrice"),
              avg("totalPrice"),
              count("transactionID"))
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min(quantity)</th><th>max(quantity)</th><th>sum(totalPrice)</th><th>avg(totalPrice)</th><th>count(transactionID)</th></tr></thead><tbody><tr><td>1</td><td>60</td><td>66471</td><td>19.943294329432945</td><td>3333</td></tr></tbody></table></div>

# %%
# %sql
select 
max(quantity) as Max,
min(quantity) as Min ,
sum(totalPrice) as Sum ,
avg(totalPrice) as Avg,
count(*) as Count
from samples.bakehouse.sales_transactions
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Max</th><th>Min</th><th>Sum</th><th>Avg</th><th>Count</th></tr></thead><tbody><tr><td>60</td><td>1</td><td>66471</td><td>19.943294329432945</td><td>3333</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import sum,avg,count,round
df2=df.groupBy("paymentMethod").agg(
    count("*").alias("count"),
    sum("totalPrice").alias("total_revenue"),
    round(avg("totalPrice"),2).alias("average_transaction")
)
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>paymentMethod</th><th>count</th><th>total_revenue</th><th>average_transaction</th></tr></thead><tbody><tr><td>amex</td><td>1106</td><td>22434</td><td>20.28</td></tr><tr><td>mastercard</td><td>1144</td><td>22263</td><td>19.46</td></tr><tr><td>visa</td><td>1083</td><td>21774</td><td>20.11</td></tr></tbody></table></div>

# %%
# %sql
select max(quantity) as Max,
min(quantity) as Min ,
sum(totalPrice) as Sum ,
round(avg(totalPrice),2) as Avg,
count(*) as Count
from samples.bakehouse.sales_transactions
group by paymentMethod
having count(*)>1100
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Max</th><th>Min</th><th>Sum</th><th>Avg</th><th>Count</th></tr></thead><tbody><tr><td>60</td><td>1</td><td>22434</td><td>20.28</td><td>1106</td></tr><tr><td>60</td><td>1</td><td>22263</td><td>19.46</td><td>1144</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import col
df2=df.groupBy("paymentMethod").count().filter(col("count")>1100)
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>paymentMethod</th><th>count</th></tr></thead><tbody><tr><td>amex</td><td>1106</td></tr><tr><td>mastercard</td><td>1144</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import collect_set,collect_list
df2=df.groupBy("paymentMethod").agg(collect_set("product"),collect_list("product"))
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select paymentMethod,collect_list(product),collect_set(product)
from samples.bakehouse.sales_transactions
group by paymentMethod
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number,rank,dense_rank

window_spec=Window.partitionBy("product").orderBy(df["quantity"].desc())
df2=df.withColumn("row_number_over_product",row_number().over(window_spec)).\
withColumn("rank_over_product",rank().over(window_spec)).\
withColumn("dense_rank_over_product",dense_rank().over(window_spec))
df3=df2.select("product","customerID","quantity","row_number_over_product","rank_over_product","dense_rank_over_product")
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df4=df3.filter(df3["row_number_over_product"]<10)
display(df4)
df4=df3.filter(df3["row_number_over_product"]==1)
display(df4)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select product,customerID,quantity,row_number() over(partition by product order by quantity desc) as row_number_over_product,
rank() over (partition by product order by quantity desc) as rank_over_product,
dense_rank() over (partition by product order by quantity desc) as dense_rank_over_product
from samples.bakehouse.sales_transactions
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
